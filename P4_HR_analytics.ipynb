# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#convert data file into Dataframe 
df=pd.read_csv('HR_data.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Observation:
#     1.There are no missing values in any column.
#     2.Some of the columns contain categorical data,which needs to be transformed.
#     3.Some of the information is not required therefore need to be dropped during cleansing of data.

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Observation:
#     mean values in employee count is almost same and standard deviation is 0.

# %%
#checking for correlation
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Finding:Light shades are highly correlated.

# %%
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# Observation:
#     1.The more number of staff are in between the age group 25-45.
#     2.Employee count and Standard hours are constant for all the employees.
#     3.Performance rate is high in employees of age group 30-31.
#     4.Employee number is the unique identification number given to the      employees.

# %%
df.drop(columns=['EmployeeNumber','Over18','EmployeeCount','StandardHours','StockOptionLevel','RelationshipSatisfaction','DailyRate','HourlyRate'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
for i in df:
    print(i,'\n',df[i].unique(),'\n\n')
# Out:
# Age
#  [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
#
#
# Attrition
#  ['Yes' 'No']
#
#
# BusinessTravel
#  ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# Department
#  ['Sales' 'Research & Development' 'Human Resources']
#
#
# DistanceFromHome
#  [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
#
#
# Education
#  [2 1 4 3 5]
#
#
# EducationField
#  ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
#
#
# EnvironmentSatisfaction
#  [2 3 4 1]
#
#
# Gender
#  ['Female' 'Male']
#
#
# JobInvolvement
#  [3 2 4 1]
#
#
# JobLevel
#  [2 1 3 4 5]
#
#
# JobRole
#  ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
#
#
# JobSatisfaction
#  [4 2 3 1]
#
#
# MaritalStatus
# ...

# %% [markdown]
# # Data Visualisation

# %%
#target variable is Attrition
print(df['Attrition'].value_counts())
sns.countplot(df['Attrition'])
plt.title('Attrition of Employee')
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# Text(0.5, 1.0, 'Attrition of Employee')

# %% [markdown]
# Finding: The rate of current employees is more than ex-employees

# %%
#Histogram
plt.hist(x='Age',bins=10,data=df)
plt.show()

# %% [markdown]
# Finding: Maximum number of emploees are aged between 30-40

# %%
print(df['Gender'].value_counts())
sns.countplot(df['Gender'])
plt.title('number of employees according to Gender')
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64
# Text(0.5, 1.0, 'number of employees according to Gender')

# %% [markdown]
# Finding: Number of male employees are more than female employees

# %%
sns.countplot(x='Gender',hue='Attrition',data=df)
plt.title('Gender Attrition rate')
# Out:
# Text(0.5, 1.0, 'Gender Attrition rate')

# %%
print(df['OverTime'].value_counts())
sns.countplot(df['OverTime'])
plt.title('Employees with overtime stat')
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64
# Text(0.5, 1.0, 'Employees with overtime stat')

# %%
sns.countplot(x='OverTime',hue='Attrition',data=df)
plt.title('Attrition rate according to over time')
# Out:
# Text(0.5, 1.0, 'Attrition rate according to over time')

# %% [markdown]
# Observation: This plot shows that the more number of employees associated with Overtime have left.

# %%
print(df['BusinessTravel'].value_counts())
sns.countplot(df['BusinessTravel'])
plt.title('Employees who travel for Business')
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Text(0.5, 1.0, 'Employees who travel for Business')

# %% [markdown]
# Finding: Majority of employees travel rarely and few never travelled.

# %%
sns.countplot(x='BusinessTravel',data=df,hue='Attrition')
plt.title('Attrition rate/Business Travel')
# Out:
# Text(0.5, 1.0, 'Attrition rate/Business Travel')

# %%
print(df['JobSatisfaction'].value_counts())
sns.countplot(df['JobSatisfaction'])
plt.title('Employess with job satisfaction')
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# Text(0.5, 1.0, 'Employess with job satisfaction')

# %%
sns.countplot(x='JobSatisfaction',hue='Attrition',data=df)

# %% [markdown]
# ### Data Distribution bt Attrition based on employee's professional history

# %%
attr_y=df[df['Attrition']=='Yes']

# %%
plt.figure(figsize=(12,15))
sns.barplot(x='EducationField',y='Education',hue='Attrition',data=attr_y)

# %%
print(df['MaritalStatus'].value_counts())
sns.countplot(df['MaritalStatus'])
plt.title('Number of employees with MaritalStatus')
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# Text(0.5, 1.0, 'Number of employees with MaritalStatus')

# %%
sns.countplot(x='MaritalStatus',data=attr_y,hue='Gender')

# %%
sns.countplot(x='NumCompaniesWorked',data=attr_y)

# %%
sns.countplot(x='TrainingTimesLastYear',data=attr_y)

# %%
sns.countplot(x='YearsWithCurrManager',data=attr_y)

# %%
sns.scatterplot(x='PercentSalaryHike',y='YearsAtCompany',data=attr_y,hue='PerformanceRating')

# %%
sns.catplot(x='YearsInCurrentRole',y='YearsAtCompany',data=attr_y,hue='Attrition',kind='point')

# %%
plt.figure(figsize=(20,8))
print(df['JobRole'].value_counts())
sns.countplot(df['JobRole'])
plt.title('Employee number according to job role')
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# Text(0.5, 1.0, 'Employee number according to job role')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='JobRole',hue='Attrition',data=attr_y)

# %% [markdown]
# observations:
#     1.Employees with marital status of single are the highest proportion of leavers.
#     2.Employees who travel frequently show highest Attrition rate.
#     3.Employees who work overtime show high attrition.
#     4.Positive correlations of Attrition are with Performance Rating,Monthly rate, Number of Companies worked,Distance from Home.
#     5.Few employees left after they reached 2 year anniversary in the company.

# %% [markdown]
# ## checking Skewness

# %%
df.skew()
# Out:
# Age                        0.413286
# DistanceFromHome           0.958118
# Education                 -0.289681
# EnvironmentSatisfaction   -0.321654
# JobInvolvement            -0.498419
# JobLevel                   1.025401
# JobSatisfaction           -0.329672
# MonthlyIncome              1.369817
# MonthlyRate                0.018578
# NumCompaniesWorked         1.026471
# PercentSalaryHike          0.821128
# PerformanceRating          1.921883
# TotalWorkingYears          1.117172
# TrainingTimesLastYear      0.553124
# WorkLifeBalance           -0.552480
# YearsAtCompany             1.764529
# YearsInCurrentRole         0.917363
# YearsSinceLastPromotion    1.984290
# YearsWithCurrManager       0.833451
# dtype: float64

# %%
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# Age                        0.413286
# DistanceFromHome           0.398114
# Education                 -0.289681
# EnvironmentSatisfaction   -0.321654
# JobInvolvement            -0.498419
# JobLevel                   0.593923
# JobSatisfaction           -0.329672
# MonthlyIncome              0.861960
# MonthlyRate                0.018578
# NumCompaniesWorked         0.031303
# PercentSalaryHike          0.655412
# PerformanceRating          1.921883
# TotalWorkingYears          0.176358
# TrainingTimesLastYear     -4.082699
# WorkLifeBalance           -1.202646
# YearsAtCompany             0.426835
# YearsInCurrentRole        -0.254344
# YearsSinceLastPromotion    0.739126
# YearsWithCurrManager      -0.254611
# dtype: float64

# %% [markdown]
# # Plotting Outliers

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# Finding: outliers found in few features such as performance rating,Total Working years,Training time last year and years at company.

# %%
df1=df.copy()
df1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales          1.000000
# 1   49        No  Travel_Frequently  Research & Development          2.828427
# 2   37       Yes      Travel_Rarely  Research & Development          1.414214
# 3   33        No  Travel_Frequently  Research & Development          1.732051
# 4   27        No      Travel_Rarely  Research & Development          1.414214
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
# ...

# %%
df1.shape
# Out:
# (1470, 27)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1.describe()))
z
# Out:
# array([[2.64453899, 2.64574102, 2.64574197, 2.64574481, 2.64574546,
#         2.64574981, 2.64574482, 2.63867304, 1.24508058, 2.64574755,
#         2.64574267, 2.64574956, 2.64573414, 2.64575009, 2.64575027,
#         2.6457347 , 2.64574384, 2.64574403, 2.64574425],
#        [0.37015578, 0.3777154 , 0.37753528, 0.37759927, 0.37717838,
#         0.37779185, 0.37759013, 0.36415779, 0.29660227, 0.37788664,
#         0.3770734 , 0.37748928, 0.37739021, 0.37745854, 0.3775297 ,
#         0.37795417, 0.37808527, 0.37837963, 0.37811827],
#        [0.428613  , 0.38059649, 0.38142751, 0.38095519, 0.3813367 ,
#         0.37989743, 0.38093996, 0.47105295, 0.56712179, 0.37910135,
#         0.38412285, 0.3809415 , 0.38149526, 0.37931602, 0.38011653,
#         0.380626  , 0.37960803, 0.37835588, 0.37954256],
#        [0.40996491, 0.38127187, 0.38147731, 0.38114699, 0.38074245,
#         0.37859305, 0.38115187, 0.45978595, 1.17017578, 0.38080491,
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# No outliers detected.

# %% [markdown]
# # Machine Learning Algorithm

# %%
#splitting x and y variables
x=df1.drop(columns=['Attrition'])
x.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales          1.000000
# 1   49  Travel_Frequently  Research & Development          2.828427
# 2   37      Travel_Rarely  Research & Development          1.414214
# 3   33  Travel_Frequently  Research & Development          1.732051
# 4   27      Travel_Rarely  Research & Development          1.414214
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2  Female               3
# 1          1  Life Sciences                        3    Male               2
# 2          2          Other                        4    Male               2
# 3          4  Life Sciences                        4  Female               3
# 4          1        Medical                        1    Male               3
#
#    JobLevel  ... OverTime  PercentSalaryHike PerformanceRating  \
# ...

# %%
y=df1['Attrition']
y.head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
x.shape
# Out:
# (1470, 26)

# %%
#Label Encoder

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# Transforming Gender and OverTime data into int
x['Gender']=le.fit_transform(x['Gender'])
x['OverTime']=le.fit_transform(x['OverTime'])

# %%
x.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales          1.000000
# 1   49  Travel_Frequently  Research & Development          2.828427
# 2   37      Travel_Rarely  Research & Development          1.414214
# 3   33  Travel_Frequently  Research & Development          1.732051
# 4   27      Travel_Rarely  Research & Development          1.414214
#
#    Education EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0          2  Life Sciences                        2       0               3
# 1          1  Life Sciences                        3       1               2
# 2          2          Other                        4       1               2
# 3          4  Life Sciences                        4       0               3
# 4          1        Medical                        1       1               3
#
#    JobLevel  ... OverTime  PercentSalaryHike PerformanceRating  \
# ...

# %%
x=pd.get_dummies(x)
x.shape
# Out:
# (1470, 45)

# %%
#Scaling of data

from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
x
# Out:
# array([[ 0.4463504 , -1.30033341, -0.89168825, ..., -0.53487311,
#         -0.91892141,  1.45864991],
#        [ 1.32236521,  0.07721147, -1.86842575, ..., -0.53487311,
#          1.08823234, -0.68556546],
#        [ 0.008343  , -0.98826312, -0.89168825, ..., -0.53487311,
#         -0.91892141,  1.45864991],
#        ...,
#        [-1.08667552, -0.5469291 ,  0.08504925, ..., -0.53487311,
#          1.08823234, -0.68556546],
#        [ 1.32236521, -0.98826312,  0.08504925, ..., -0.53487311,
#          1.08823234, -0.68556546],
#        [-0.32016256,  0.07721147,  0.08504925, ..., -0.53487311,
#          1.08823234, -0.68556546]])

# %%
y=le.fit_transform(y)
y.shape
# Out:
# (1470,)

# %%
y
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42,stratify=y)

# %%
print('x_train.shape:',x_train.shape,'x_test.shape:',x_test.shape,'\ny_train.shape:',y_train.shape,'y_test.shape:',y_test.shape)
# Out:
# x_train.shape: (1029, 45) x_test.shape: (441, 45)
# y_train.shape: (1029,) y_test.shape: (441,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
#KNeighbors Classifier

knn=KNeighborsClassifier()
neighbors={'n_neighbors':range(1,30)}
bknn=GridSearchCV(knn,neighbors)
bknn.fit(x_train,y_train)
bknn.best_params_
# Out:
# {'n_neighbors': 5}

# %%
KNN=KNeighborsClassifier(n_neighbors=5)

# %%
#SVC

svc=SVC()
svc_parameters={'kernel':['linear','sigmoid','poly','rbf'],'C':[1,10]}
bsvc=GridSearchCV(svc,svc_parameters)
bsvc.fit(x_train,y_train)
bsvc.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
SV=SVC(kernel='linear',C=1)

# %%
#DTC
criterion={'criterion':['gini','entropy']}
dtc=DecisionTreeClassifier(random_state=42)
bdtc=GridSearchCV(dtc,criterion)
bdtc.fit(x_train,y_train)
bdtc.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
DTC=DecisionTreeClassifier(criterion='entropy',random_state=42)

# %%
#Random_Forest_Classifier

parameters={'n_estimators':range(100,200,300)}
rf=RandomForestClassifier(random_state=42)
brf=GridSearchCV(rf,parameters)
brf.fit(x_train,y_train)
brf.best_params_
# Out:
# {'n_estimators': 100}

# %%
RFC=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
#Gradient Boosting Classifier

GBC=GradientBoostingClassifier(n_estimators=250)

# %%
#ExtraTreesClassifier

ETC=ExtraTreesClassifier(n_estimators=250)

# %%
#AdaBoostClassifier

ABC=AdaBoostClassifier(n_estimators=50)

# %%
#BaggingClassifier

BC=BaggingClassifier(n_estimators=250)

# %%
KNN=KNeighborsClassifier(n_neighbors=5)
SV=SVC(kernel='linear',C=1)
LR=LogisticRegression()
DT=DecisionTreeClassifier(criterion='entropy',random_state=42)
GNB=GaussianNB()
RFC=RandomForestClassifier(n_estimators=100,random_state=42)
GBC=GradientBoostingClassifier(n_estimators=250)
ETC=ExtraTreesClassifier(n_estimators=250)
ABC=AdaBoostClassifier(n_estimators=50)
BC=BaggingClassifier(n_estimators=250)

# %%
models=[]
models.append(('KNeighborsClassifier',KNN))
models.append(('SVC',SV))
models.append(('LogisticRegression',LR))
models.append(('DecisionTreeClassifier',DT))
models.append(('GaussianNB',GNB))
models.append(('RandomForestClassifier',RFC))
models.append(('GradientBoostingClassifier',GBC))
models.append(('ExtraTreesClassifier',ETC))
models.append(('AdaBoostClassifier',ABC))
models.append(('BaggingClassifier',BC))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
CVS=[]
rocscore=[]

for name,model in models:
    print('*******************',name,'***************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy Score:',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    
    print('Cross val score:',sc)
    CVS.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score:',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right') 
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# ******************* KNeighborsClassifier ***************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# Accuracy Score: 0.8503401360544217
#
#
# Cross val score: 0.8523809523809524
#
#
# roc_auc_score: 0.5636657784545109
#
#
# classification report
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       370
#            1       0.67      0.14      0.23        71
#
#     accuracy                           0.85       441
#    macro avg       0.76      0.56      0.57       441
# weighted avg       0.83      0.85      0.81       441
#
#
#
# [[365   5]
#  [ 61  10]]
#
#
#
#
#
# ******************* SVC ***************
#
#
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
# ...

# %%
final=pd.DataFrame({'Model':Model,'Accuracy score':score,'cross_val_score':CVS,'Roc_auc_curve':rocscore})

final
# Out:
#                         Model  Accuracy score  cross_val_score  Roc_auc_curve
# 0        KNeighborsClassifier       85.034014        85.238095      56.366578
# 1                         SVC       87.074830        88.639456      66.119147
# 2          LogisticRegression       86.848073        88.503401      65.414922
# 3      DecisionTreeClassifier       76.190476        79.183673      57.356300
# 4                  GaussianNB       69.841270        71.156463      66.661591
# 5      RandomForestClassifier       83.219955        85.850340      54.716407
# 6  GradientBoostingClassifier       83.446712        86.190476      59.973354
# 7        ExtraTreesClassifier       84.580499        86.054422      57.234488
# 8          AdaBoostClassifier       84.580499        87.755102      61.218120
# 9           BaggingClassifier       83.446712        85.850340      57.696993

# %% [markdown]
# Conclusion:
#     Different models were used to find the Attrition,its found that Logistic Regression is the best model,from which 86% accuracy is achieved.

# %%
#save the model

import joblib
from joblib import dump
joblib.dump(LR,'LR_HR_Analysis.pkl')
# Out:
# ['LR_HR_Analysis.pkl']
