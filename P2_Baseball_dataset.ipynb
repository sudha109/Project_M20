# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Observation:
#     W-Total number of games won.
#     R-Number of runs scored.
#     AB-Bat on the pitch,but not hit.
#     H-Hit the ball without getting out.
#     2B-Double hit.
#     3B-Triple hit.
#     HR-Total home runs.
#     BB-base on balls.
#     SO-Strike out.
#     SB-Stolen base.
#     RA-Average runs.
#     ER-Earned run.
#     ERA-Earned run average.
#     CG-complete game.
#     SHO-Shut out.
#     SV-save.
#     E-Errors.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Observation:
#     1.there are no missing values in the data set.
#     2.there are 30 rows and 17 columns in the dataframe.
#     3.no object type data found.
#     4.The above data is continuous hence Linear Regression algorithm is used to     predict the number of wins.

# %% [markdown]
# # Checking null values.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Statistical Summary.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Observations:
#     1.Standard Deviation in SO is very high.
#     2.mean value is highest in AB.
#     3.difference between the values of 75% and max is almost the same with very small differences.

# %%
#Finding correlation
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),cmap='rocket',annot=True)

# %% [markdown]
# Findings:
#     1.Light shades means values are highly corelated.
#     2.W is negatively corelated with ERA,ER and RA and positively correlated       with SV.
#     3.W is positively corelated with SV,SHO,BB,2B,R.

# %% [markdown]
# # Visualisation of data

# %%
sns.set(style='whitegrid')
sns.violinplot(x='SV',data=df)
plt.title("save")
plt.show()

# %% [markdown]
# observation: Winning rate is high when SV values are between 40-50.

# %%
sns.set(style='whitegrid')
sns.violinplot(x='SHO',data=df)
plt.title("pitches with no runs allowed")
plt.show()

# %% [markdown]
# Observation: Winning rate is high when the values of SHO is between 10-15.

# %%
sns.set(style='whitegrid')
sns.violinplot(x='R',data=df)
plt.title("Runs")
plt.show()

# %% [markdown]
# Observation: Winning chances are high when the runs scored is between 650-700.

# %%
sns.set(style='whitegrid')
sns.violinplot(x='2B',data=df)
plt.title("Double hits")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(x='RA',data=df)
plt.title("Run Average")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(x='ERA',data=df)
plt.title("Earned Run Average")
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(x='ER',data=df)
plt.title("Earned runs")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#changes in ER with respect to RA
sns.lineplot(x=df['ER'],y=df['RA'],data=df)
plt.show()

# %% [markdown]
# The above plot shows increase in RA with respect to ER accordingly.

# %%
#changes in W with respect to ER
sns.lineplot(x=df['ER'],y=df['W'],data=df)
plt.show()

# %%
plt.scatter(df['SV'],df['W'])
plt.show()

# %% [markdown]
# winning rate is more when value of SV is beyond 40.

# %%
plt.scatter(df['SHO'],df['W'])
plt.show()

# %%
plt.scatter(df['R'],df['W'])
plt.show()

# %%
plt.scatter(df['2B'],df['W'])
plt.show()

# %%
plt.scatter(df['RA'],df['W'])
plt.show()

# %%
plt.scatter(df['ER'],df['W'])
plt.show()

# %%
plt.scatter(df['ERA'],df['W'])
plt.show()

# %% [markdown]
# ERA value is more then the winning rate is more.

# %% [markdown]
# # Checking Skewness.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Skewness is present in R,H,HR,SB,CG,SV and E.

# %%
#Applying Distribution plot for all the columns.
#using for loop for all the numerical columns,we use df.describe() to discriminate numerical columns from categorical

for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
#elimination skewness in the data
import numpy as np
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
#cross checking for skewness
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.649567
# 2B    -0.230650
# 3B     0.129502
# HR     0.264948
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.311476
# SHO   -0.061761
# SV     0.410288
# E      0.763487
# dtype: float64

# %% [markdown]
# Observation:After removing the skewness in R,H and E still some skewness is present.

# %%
print(df['E'].describe())
sns.countplot(df['E'])
# Out:
# count    30.000000
# mean      9.687994
# std       0.701800
# min       8.660254
# 25%       9.273618
# 50%       9.539248
# 75%       9.836133
# max      11.224972
# Name: E, dtype: float64

# %%
print(df['R'].describe())
sns.countplot(df['R'])
# Out:
# count    30.000000
# mean     26.211930
# std       1.099235
# min      23.937418
# 25%      25.519565
# 50%      26.248809
# 75%      26.800127
# max      29.849623
# Name: R, dtype: float64

# %%
print(df['H'].describe())
sns.countplot(df['H'])
# Out:
# count    30.000000
# mean     37.456345
# std       0.758091
# min      36.386811
# 25%      36.918830
# 50%      37.181984
# 75%      38.097803
# max      38.923001
# Name: H, dtype: float64

# %% [markdown]
# # Plotting Outliers

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# Most number of outliers are present in E.

# %% [markdown]
# # Removing Outliers

# %%
df1=df.copy()
df1.head()
# Out:
#     W          R    AB          H   2B  3B         HR   BB    SO   SB   RA  \
# 0  95  26.907248  5575  38.691084  300  42  11.789826  383   973  104  641
# 1  83  26.381812  5467  36.728735  277  44  12.489996  439  1264   70  700
# 2  81  25.865034  5439  37.349699  303  29  11.874342  533  1157   86  640
# 3  76  24.939928  5533  37.161808  260  27  11.661904  404  1231   68  701
# 4  74  26.248809  5605  38.923001  289  49  12.288206  455  1259   83  803
#
#     ER   ERA        CG       SHO        SV          E
# 0  601  3.73  1.414214  2.828427  7.483315   9.380832
# 1  653  4.07  1.414214  3.464102  6.708204   9.273618
# 2  584  3.67  3.316625  3.162278  6.164414   8.888194
# 3  643  3.98  2.645751  3.000000  6.082763  10.049876
# 4  746  4.64  2.645751  3.464102  5.916080   9.273618

# %%
df1.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[1.36540860e+00, 6.43360457e-01, 8.47731264e-01, 1.65659155e+00,
#         1.42017307e+00, 1.04119304e+00, 7.79588836e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 2.92055667e-01, 7.81873120e-01, 1.62988184e+00,
#         4.45160189e-01],
#        [1.97838300e-01, 1.57187245e-01, 7.11093535e-01, 9.76199843e-01,
#         1.27403389e-01, 1.23580856e+00, 2.01722201e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 2.92055667e-01, 2.59566641e-01, 2.95192242e-01,
#         6.00540408e-01],
#        [3.24325082e-03, 3.20974401e-01, 1.11523330e+00, 1.43082336e-01,
#         1.58879521e+00, 2.23807850e-01, 7.09835826e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 1.96563341e+00, 2.34918307e-01, 6.41178049e-01,
#         1.15912252e+00],
# ...

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z[5][1]
# Out:
# 3.365867919765219

# %%
df1_new=df1[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (30, 17)

# %%
df1_new.shape
# Out:
# (29, 17)

# %% [markdown]
# One row is removed as outlier.

# %%
df1=df1_new
df1.shape
# Out:
# (29, 17)

# %%
#Splitting x and y variables

x=df1.drop(['W'],axis=1)
x.shape
# Out:
# (29, 16)

# %%
y=df1['W']
y.shape
# Out:
# (29,)

# %%
#Using Standard Scaler to scale the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.95651645,  0.83008422,  1.73108753,  1.55653766,  1.01084549,
#         -0.75401669, -1.53635899, -2.72762331,  0.9059529 , -0.66451353,
#         -0.51114812, -0.51138828, -0.25354897, -0.77743601,  1.60263096,
#         -0.45432526],
#        [ 0.34416795, -0.70283074, -0.94430524,  0.20117132,  1.20891656,
#         -0.13904468, -0.49502051,  0.12189552, -0.58531515,  0.15463823,
#          0.23216082,  0.23895226, -0.25354897,  0.24747497,  0.25562074,
#         -0.60761852],
#        [-0.25808975, -1.10025314, -0.097707  ,  1.73332457, -0.2766165 ,
#         -0.67978478,  1.25294051, -0.9258657 ,  0.11645805, -0.67839746,
#         -0.75415297, -0.64380131,  2.02046293, -0.23916196, -0.68939326,
#         -1.15869812],
#        [-1.33621796,  0.23395062, -0.35386977, -0.8006212 , -0.47468758,
#         -0.86637322, -1.14585706, -0.20124579, -0.6730368 ,  0.16852216,
#          0.08921679,  0.04033271,  1.21854679, -0.50080556, -0.83128957,
#          0.50227443],
# ...

# %% [markdown]
# # Machine Learning Algorithm

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import joblib
from joblib import dump

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print('x_train.shape:',x_train.shape,'x_test.shape:',x_test.shape,'\ny_train.shape:',y_train.shape,'y_test.shape:',y_test.shape)
# Out:
# x_train.shape: (23, 16) x_test.shape: (6, 16)
# y_train.shape: (23,) y_test.shape: (6,)

# %%
from sklearn.metrics import mean_squared_error, r2_score
def models(model, x_train, x_test, y_train, y_test,score,rmse):
    #Fit the algorithm on the data
    model.fit(x_train, y_train)
    
    #Predict training set:
    y_pred = model.predict(x_test)
    
    score.append(model.score(x_train,y_train))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    
    print('\nModel Report')
    print('Score:',model.score(x_train,y_train))
    print('RMSE:',np.sqrt(mean_squared_error(y_test, y_pred)))
    print('R2 Score:',r2_score(y_test, y_pred))

# %%
model_name,score,rmse=[],[],[]

# %%
#Linear Regression

lreg=LinearRegression()
models(lreg,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('Linear Regression')
# Out:
# Model Report
# Score: 0.9676825870075806
# RMSE: 7.887856784678558
# R2 Score: 0.35413545340208075

# %%
#Ridge Regression

parameters={'alpha':[0.001,0.01,1]}
best=GridSearchCV(Ridge(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 1}

# %%
rr=Ridge(alpha=1)
models(rr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('Ridge Regression')
# Out:
# Model Report
# Score: 0.936712638329962
# RMSE: 5.439549396541788
# R2 Score: 0.6928508895769745

# %%
#Lasso Regression

parameters={'alpha':[0.001,0.01,1]}
best=GridSearchCV(Ridge(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 1}

# %%
lr=Lasso(alpha=1)
models(lr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('Lasso Regression')
# Out:
# Model Report
# Score: 0.8868364338924676
# RMSE: 4.597478076507454
# R2 Score: 0.7805868027961935

# %%
#ElasticNet

enr=ElasticNet(alpha=0.01)
models(enr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('ElasticNet')
# Out:
# Model Report
# Score: 0.9478689675600309
# RMSE: 4.88072638660654
# R2 Score: 0.7527180962534533

# %%
#Support Vector Regression

parameters={'kernel':['linear','poly','rbf']}
best=GridSearchCV(SVR(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'kernel': 'linear'}

# %%
svr=SVR(kernel='linear')
models(svr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('Support Vector Regression')
# Out:
# Model Report
# Score: 0.9154844011875746
# RMSE: 5.307869322974945
# R2 Score: 0.7075417638431297

# %%
#Decision Tree Regressor model

parameters={'max_depth':[8,10,12,15],'min_samples_leaf':[100,150]}
best=GridSearchCV(DecisionTreeRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 8, 'min_samples_leaf': 100}

# %%
dct=DecisionTreeRegressor(max_depth=8,min_samples_leaf=100)
models(dct,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('DecisionTreeRegression')
# Out:
# Model Report
# Score: 0.0
# RMSE: 9.839576478711026
# R2 Score: -0.005023515021487235

# %%
#Random Forest Regressor

parameters={'n_estimators':[200,300,400],'max_depth':[5,6]}
best=GridSearchCV(RandomForestRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 200}

# %%
rf=RandomForestRegressor(n_estimators=300,max_depth=6)
models(rf,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('RandomForestRegression')
# Out:
# Model Report
# Score: 0.9474533081694069
# RMSE: 6.857690733520835
# R2 Score: 0.5118208768517212

# %%
final=pd.DataFrame({'Model name':model_name,'Score':score,'RMSE':rmse})
final
# Out:
#                   Model name     Score      RMSE
# 0          Linear Regression  0.967683  7.887857
# 1           Ridge Regression  0.936713  5.439549
# 2           Lasso Regression  0.886836  4.597478
# 3                 ElasticNet  0.947869  4.880726
# 4  Support Vector Regression  0.915484  5.307869
# 5     DecisionTreeRegression  0.000000  9.839576
# 6     RandomForestRegression  0.947453  6.857691

# %%
#saving the model

joblib.dump(lreg,'Baseball Data.pkl')
# Out:
# ['Baseball Data.pkl']
