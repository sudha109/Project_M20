# %%
#import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#import avocado data as dataframe
df=pd.read_csv('avocado.csv',parse_dates=['Date'])
df
# Out:
#            Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0    2015-12-27          1.33      64236.62   1036.74   54454.85     48.16
# 1    2015-12-20          1.35      54876.98    674.28   44638.81     58.33
# 2    2015-12-13          0.93     118220.22    794.70  109149.67    130.50
# 3    2015-06-12          1.08      78992.15   1132.00   71976.41     72.58
# 4    2015-11-29          1.28      51039.60    941.48   43838.39     75.78
# ...         ...           ...           ...       ...        ...       ...
# 1512 2016-10-16          1.39     190846.01  57529.11   56366.66  17531.78
# 1513 2016-09-10          1.51     178235.75  43325.87   52189.61  19419.57
# 1514 2016-02-10          1.48     178410.82  46364.75   52893.38  16736.92
# 1515 2016-09-25          1.47     189131.52  54110.79   53593.58  17495.42
# 1516 2016-09-18          1.43     182978.30  43116.41   54193.42  16563.91
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0        8696.87     8603.62       93.25         0.00  conventional  2015
# 1        9505.56     9408.07       97.49         0.00  conventional  2015
# 2        8145.35     8042.21      103.14         0.00  conventional  2015
# 3        5811.16     5677.40      133.76         0.00  conventional  2015
# 4        6183.95     5986.26      197.69         0.00  conventional  2015
# ...          ...         ...         ...          ...           ...   ...
# 1512    59418.46    48823.53    10354.65       240.28  conventional  2016
# 1513    63300.70    54704.14     8596.56         0.00  conventional  2016
# 1514    62415.77    53332.61     8258.16       825.00  conventional  2016
# 1515    63931.73    55653.47     8278.26         0.00  conventional  2016
# 1516    69104.56    57456.21    11648.35         0.00  conventional  2016
#
#          region
# 0        Albany
# 1        Albany
# 2        Albany
# 3        Albany
# 4        Albany
# ...         ...
# 1512  Charlotte
# 1513  Charlotte
# 1514  Charlotte
# 1515  Charlotte
# 1516  Charlotte
#
# [1517 rows x 13 columns]

# %%
df.shape
# Out:
# (1517, 13)

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %% [markdown]
# Observation:
#     1.All the columns are in float data type except year,type and region
#     2.year column is of data type int
#     3.type and region columns are object data type or categorical data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   datetime64[ns]
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   int64
#  12  region        1517 non-null   object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 154.2+ KB

# %% [markdown]
# Observation:
#     1.There are no missing values
#     2.data contains 1517 rows and 13 columns

# %%
#changing the data type of type and region columns

df['type']=df['type'].astype('category')
df['region']=df['region'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   datetime64[ns]
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   category
#  11  year          1517 non-null   int64
#  12  region        1517 non-null   category
# dtypes: category(2), datetime64[ns](1), float64(9), int64(1)
# memory usage: 136.4 KB

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# std    7.579765e+05  6.474765e+05  1.182157e+05    7455.712144     0.369324
# min    3.311770e+03  3.311770e+03  0.000000e+00       0.000000  2015.000000
# 25%    3.620689e+04  2.972722e+04  5.407400e+02       0.000000  2015.000000
# 50%    7.397906e+04  6.237569e+04  5.044350e+03       0.000000  2015.000000
# 75%    1.576097e+05  1.461994e+05  2.926767e+04     401.480000  2015.000000
# max    6.736304e+06  5.893642e+06  1.121076e+06  108072.790000  2016.000000

# %% [markdown]
# Observations:
#     1.min,25% and 50% of Xlarge bags is 0.

# %%
#correlation

df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# Total Volume    0.967689    0.960642    0.910226     0.521717 -0.004189
# 4046            0.930395    0.922278    0.884229     0.474063 -0.040439
# 4225            0.951779    0.943988    0.900496     0.504718 -0.007254
# 4770            0.926405    0.923607    0.840523     0.646053  0.029222
# Total Bags      1.000000    0.997341    0.911336     0.601856  0.090108
# Small Bags      0.997341    1.000000    0.879131     0.611300  0.106382
# Large Bags      0.911336    0.879131    1.000000     0.447779 -0.018678
# XLarge Bags     0.601856    0.611300    0.447779     1.000000  0.218342
# year            0.090108    0.106382   -0.018678     0.218342  1.000000

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),cmap='rocket',annot=True)

# %% [markdown]
# Observations:
#     1.Lighter shades are highly correlated
#     2.Average price is negatively correlated to all the columns
#     3.Xlarge bags are highly positively correlated to all the columns

# %% [markdown]
# # Exploratory Data Analysis

# %%
for i in df:
    print(i,'\n',df[i].unique(),'\n')
# Out:
# Date
#  ['2015-12-27T00:00:00.000000000' '2015-12-20T00:00:00.000000000'
#  '2015-12-13T00:00:00.000000000' '2015-06-12T00:00:00.000000000'
#  '2015-11-29T00:00:00.000000000' '2015-11-22T00:00:00.000000000'
#  '2015-11-15T00:00:00.000000000' '2015-08-11T00:00:00.000000000'
#  '2015-01-11T00:00:00.000000000' '2015-10-25T00:00:00.000000000'
#  '2015-10-18T00:00:00.000000000' '2015-11-10T00:00:00.000000000'
#  '2015-04-10T00:00:00.000000000' '2015-09-27T00:00:00.000000000'
#  '2015-09-20T00:00:00.000000000' '2015-09-13T00:00:00.000000000'
#  '2015-06-09T00:00:00.000000000' '2015-08-30T00:00:00.000000000'
#  '2015-08-23T00:00:00.000000000' '2015-08-16T00:00:00.000000000'
#  '2015-09-08T00:00:00.000000000' '2015-02-08T00:00:00.000000000'
#  '2015-07-26T00:00:00.000000000' '2015-07-19T00:00:00.000000000'
#  '2015-12-07T00:00:00.000000000' '2015-05-07T00:00:00.000000000'
#  '2015-06-28T00:00:00.000000000' '2015-06-21T00:00:00.000000000'
#  '2015-06-14T00:00:00.000000000' '2015-07-06T00:00:00.000000000'
#  '2015-05-31T00:00:00.000000000' '2015-05-24T00:00:00.000000000'
#  '2015-05-17T00:00:00.000000000' '2015-10-05T00:00:00.000000000'
#  '2015-03-05T00:00:00.000000000' '2015-04-26T00:00:00.000000000'
#  '2015-04-19T00:00:00.000000000' '2015-12-04T00:00:00.000000000'
#  '2015-05-04T00:00:00.000000000' '2015-03-29T00:00:00.000000000'
#  '2015-03-22T00:00:00.000000000' '2015-03-15T00:00:00.000000000'
#  '2015-08-03T00:00:00.000000000' '2015-01-03T00:00:00.000000000'
#  '2015-02-22T00:00:00.000000000' '2015-02-15T00:00:00.000000000'
#  '2015-08-02T00:00:00.000000000' '2015-01-02T00:00:00.000000000'
#  '2015-01-25T00:00:00.000000000' '2015-01-18T00:00:00.000000000'
#  '2015-11-01T00:00:00.000000000' '2015-04-01T00:00:00.000000000'
#  '2016-12-25T00:00:00.000000000' '2016-12-18T00:00:00.000000000'
#  '2016-11-12T00:00:00.000000000' '2016-04-12T00:00:00.000000000'
#  '2016-11-27T00:00:00.000000000' '2016-11-20T00:00:00.000000000'
#  '2016-11-13T00:00:00.000000000' '2016-06-11T00:00:00.000000000'
#  '2016-10-30T00:00:00.000000000' '2016-10-23T00:00:00.000000000'
#  '2016-10-16T00:00:00.000000000' '2016-09-10T00:00:00.000000000'
#  '2016-02-10T00:00:00.000000000' '2016-09-25T00:00:00.000000000'
#  '2016-09-18T00:00:00.000000000' '2016-08-05T00:00:00.000000000'
#  '2016-01-05T00:00:00.000000000' '2016-04-24T00:00:00.000000000'
#  '2016-04-17T00:00:00.000000000' '2016-10-04T00:00:00.000000000'
#  '2016-03-04T00:00:00.000000000' '2016-03-27T00:00:00.000000000'
#  2.9919690e+04 2.8709030e+04 2.7954840e+04 2.9342750e+04 2.3290740e+04
#  3.2670580e+04 3.6591190e+04 2.6579430e+04 2.8538340e+04 3.7712620e+04
#  4.1117010e+04 2.8399830e+04 2.5873300e+04 2.9990190e+04 3.7788550e+04
#  3.1034450e+04 3.5738220e+04 3.4328610e+04 2.5714930e+04 2.6718840e+04
#  3.3541910e+04 4.0842240e+04 2.8909540e+04 3.0289930e+04 2.7501390e+04
#  2.8247080e+04 3.2186130e+04 3.0374150e+04 1.9350790e+04 2.5136120e+04
#  1.7124030e+04 2.0523370e+04 2.1076610e+04 1.9681740e+04 1.7277530e+04
#  2.1064410e+04 1.8996980e+04 1.9126710e+04 2.2853110e+04 1.7870860e+04
#  1.5277680e+04 1.5578370e+04 1.7495300e+04 1.4505170e+04 1.5340520e+04
#  1.8330900e+04 1.6499430e+04 1.0604730e+04 6.9440000e+01 2.4028000e+02
#  8.2500000e+02]
#
# type
#  [conventional]
# Categories (1, object): [conventional]
#
# year
#  [2015 2016]
#
# region
#  [Albany, Atlanta, BaltimoreWashington, Boise, Boston, ..., Syracuse, Tampa, TotalUS, West, WestTexNewMexico]
# Length: 51
# Categories (51, object): [Albany, Atlanta, BaltimoreWashington, Boise, ..., Tampa, TotalUS, West, WestTexNewMexico]

# %%
df_dates=pd.DataFrame()
df_dates['month']=df['Date'].dt.month_name()
df_dates['year']=df['Date'].dt.year
df_dates['day']=df['Date'].dt.day_name()
df_dates['AveragePrice']=df['AveragePrice']
df_dates['region']=df['region']
df_dates['type']=df['type']
df_dates
# Out:
#           month  year        day  AveragePrice     region          type
# 0      December  2015     Sunday          1.33     Albany  conventional
# 1      December  2015     Sunday          1.35     Albany  conventional
# 2      December  2015     Sunday          0.93     Albany  conventional
# 3          June  2015     Friday          1.08     Albany  conventional
# 4      November  2015     Sunday          1.28     Albany  conventional
# ...         ...   ...        ...           ...        ...           ...
# 1512    October  2016     Sunday          1.39  Charlotte  conventional
# 1513  September  2016   Saturday          1.51  Charlotte  conventional
# 1514   February  2016  Wednesday          1.48  Charlotte  conventional
# 1515  September  2016     Sunday          1.47  Charlotte  conventional
# 1516  September  2016     Sunday          1.43  Charlotte  conventional
#
# [1517 rows x 6 columns]

# %%
plt.figure(figsize=(12,12))
sns.barplot(x='month',y='AveragePrice',data=df_dates)
plt.show()

# %% [markdown]
# Observation:
#     Average price does not vary in any month and price is almost the same in all months

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="month",y="AveragePrice",hue='type',data=df_dates)
plt.show()

# %%
sns.barplot(x='day',y='AveragePrice',data=df_dates)
plt.show()

# %%
sns.barplot(x='year',y='AveragePrice',data=df_dates)
plt.show()

# %% [markdown]
# Average price in 2015 is less compared to the prices in the year 2016

# %% [markdown]
# # Data Visualisation

# %%
sns.catplot(x='region',y='AveragePrice',data=df_dates,kind='bar',aspect=4)
plt.xticks(rotation=60)
plt.xlabel('Region')
plt.ylabel('AveragePrice')
plt.title('AveragePrice of Avocado')
plt.show()

# %%
df.sort_values(["AveragePrice","year"],ascending=[True,False])
# Out:
#            Date  AveragePrice  Total Volume        4046        4225  \
# 760  2015-12-27          0.49    1137707.43   738314.80   286858.37
# 796  2015-04-19          0.51    1366844.88  1097285.22   164460.99
# 789  2015-07-06          0.52    1457359.83  1130917.54   199669.94
# 761  2015-12-20          0.53    1097224.25   785254.94   204147.30
# 788  2015-06-14          0.53    1353850.06  1046887.77   180388.89
# ...         ...           ...           ...         ...         ...
# 1413 2016-11-20          1.63      78675.66     1426.31    52281.34
# 1508 2016-11-13          1.64     144089.12    49399.39    26597.39
# 1411 2016-04-12          1.66      72203.16      960.31    54243.42
# 1457 2016-06-11          1.68    3395058.42  1111431.87  1333386.69
# 1458 2016-10-30          1.68    3139833.50  1126017.42  1186843.99
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 760    11642.46   100891.80    70749.02    30142.78         0.00
# 796     7534.30    97564.37    44646.67    52917.70         0.00
# 789     4499.84   122272.51    90030.35    32242.16         0.00
# 761    10346.68    97475.33    72169.92    25305.41         0.00
# 788     4263.45   122309.95    94240.24    28069.71         0.00
# ...         ...         ...         ...         ...          ...
# 1413      27.83    24940.18    24940.18        0.00         0.00
# 1508   22714.68    45377.66    38436.79     6940.87         0.00
# 1411      22.85    16976.58    15683.05     1256.03        37.50
# 1457  120964.40   829275.46   763934.88    35997.83     29342.75
# 1458   92064.47   734907.62   686375.28    25241.60     23290.74
#
#               type  year            region
# 760   conventional  2015     PhoenixTucson
# 796   conventional  2015     PhoenixTucson
# 789   conventional  2015     PhoenixTucson
# 761   conventional  2015     PhoenixTucson
# 788   conventional  2015     PhoenixTucson
# ...            ...   ...               ...
# 1413  conventional  2016  BuffaloRochester
# 1508  conventional  2016         Charlotte
# 1411  conventional  2016  BuffaloRochester
# 1457  conventional  2016        California
# 1458  conventional  2016        California
#
# [1517 rows x 13 columns]

# %% [markdown]
# Observation: Month and date has no effect on the prices,hence the year column can be dropped regardless of any loss of the data.

# %%
df.drop(columns=['Date'],inplace=True)
df
# Out:
#       AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0             1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1             1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2             0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3             1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4             1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...            ...           ...       ...        ...       ...         ...
# 1512          1.39     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513          1.51     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514          1.48     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515          1.47     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516          1.43     182978.30  43116.41   54193.42  16563.91    69104.56
#
#       Small Bags  Large Bags  XLarge Bags          type  year     region
# 0        8603.62       93.25         0.00  conventional  2015     Albany
# 1        9408.07       97.49         0.00  conventional  2015     Albany
# 2        8042.21      103.14         0.00  conventional  2015     Albany
# 3        5677.40      133.76         0.00  conventional  2015     Albany
# 4        5986.26      197.69         0.00  conventional  2015     Albany
# ...          ...         ...          ...           ...   ...        ...
# 1512    48823.53    10354.65       240.28  conventional  2016  Charlotte
# 1513    54704.14     8596.56         0.00  conventional  2016  Charlotte
# 1514    53332.61     8258.16       825.00  conventional  2016  Charlotte
# 1515    55653.47     8278.26         0.00  conventional  2016  Charlotte
# 1516    57456.21    11648.35         0.00  conventional  2016  Charlotte
#
# [1517 rows x 12 columns]

# %%
#Distribution plot of the price

plt.figure(figsize=(9,5))
plt.title("Distribution Price")
ax=sns.distplot(df["AveragePrice"],color='r')

# %%
sns.boxplot(y="type",x="AveragePrice",data=df,palette='pink')

# %%
Year=df[['Total Volume','AveragePrice']].groupby(df.year).sum()
Year.plot(kind='line',fontsize=14,figsize=(14,8))
plt.show()

# %% [markdown]
# AveragePrice is not proportional to total volume

# %%
plt.figure(figsize=(15,18))
sns.barplot(x='AveragePrice',y='region',data=df,palette='Blues_d')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AveragePrice',y='region',data=df)

# %%
#AveragePrice according to each year
plt.figure(figsize=(15,4))
sns.lineplot(x="year",y="AveragePrice",hue='type',data=df)

# %%
df[['4046','4225','4770']].groupby(df['AveragePrice']).sum().plot(kind='line',figsize=(15,4))

# %%
Bags=df[['Small Bags','Large Bags']].groupby(df.region).sum()
Bags.plot(kind='line',fontsize=14,figsize=(14,8))
plt.show()

# %%
sns.pairplot(df.iloc[:,5:8])

# %% [markdown]
# # Skewness Distribution

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %% [markdown]
# Finding:Lot of skewness is present in all the columns except AveragePrice

# %%
for i in df.iloc[:,0:9]:
    sns.distplot(df[i])
    plt.show()

# %%
#removing skewness

df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df.skew().loc[col]>0.5:
            df[col]=np.sqrt(df[col])
        if df.skew().loc[col]<-0.5:
            df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    3.129360
# 4046            2.883385
# 4225            2.891611
# 4770            2.531303
# Total Bags      2.951677
# Small Bags      2.956167
# Large Bags      2.517165
# XLarge Bags     2.916661
# year            1.828332
# dtype: float64

# %% [markdown]
# # Plotting Outliers

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %%
df1=df.copy()
df2=df.copy()
df3=df.copy()

# %%
df1.head()
# Out:
#    AveragePrice  Total Volume       4046        4225       4770  Total Bags  \
# 0          1.33    253.449443  32.198447  233.355630   6.939741   93.257010
# 1          1.35    234.258362  25.966902  211.278986   7.637408   97.496461
# 2          0.93    343.831674  28.190424  330.378071  11.423660   90.251593
# 3          1.08    281.055422  33.645208  268.284196   8.519390   76.230965
# 4          1.28    225.919455  30.683546  209.376193   8.705171   78.638095
#
#    Small Bags  Large Bags  XLarge Bags          type       year  region
# 0   92.755701    9.656604          0.0  conventional  44.888751  Albany
# 1   96.995206    9.873702          0.0  conventional  44.888751  Albany
# 2   89.678370   10.155787          0.0  conventional  44.888751  Albany
# 3   75.348524   11.565466          0.0  conventional  44.888751  Albany
# 4   77.370925   14.060228          0.0  conventional  44.888751  Albany

# %%
df1.shape
# Out:
# (1517, 12)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1.describe()))
z
# Out:
# array([[2.64575038, 0.00378169, 0.3816203 , 0.36614815, 2.0121178 ,
#         0.96432765, 1.05931614, 2.11107324, 2.58631627, 2.64455773],
#        [0.3777247 , 0.31286665, 0.37734361, 0.36611083, 0.49033439,
#         0.40483071, 0.42262072, 0.49436584, 0.44726322, 0.36468662],
#        [0.37949201, 0.32118529, 0.2862942 , 0.360061  , 0.43512131,
#         0.4257662 , 0.43796877, 0.4297899 , 0.4033072 , 0.45644223],
#        [0.37889145, 0.66868199, 0.73948322, 0.74945877, 0.75057948,
#         0.81141132, 0.80789805, 0.73408121, 0.48854037, 0.36469033],
#        [0.37791416, 0.57441466, 0.64861558, 0.62734881, 0.69560432,
#         0.6499128 , 0.6609368 , 0.69046836, 0.48854037, 0.36469033],
#        [0.37771471, 0.44817802, 0.54133749, 0.5208228 , 0.59089629,
#         0.55049511, 0.56199432, 0.60087549, 0.48854037, 0.36469033],
#        [0.37749532, 0.26873161, 0.29501676, 0.25450991, 0.4395541 ,
#         0.39839349, 0.39233519, 0.41322212, 0.4479268 , 0.36469033],
#        [0.37651803, 2.5978399 , 2.50647055, 2.51216397, 1.38997209,
#         2.27648198, 2.22443772, 1.25172967, 0.17780206, 0.36466756]])

# %%
#threshold=3

print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# Oservation: No outliers detected.

# %%
df1.head()
# Out:
#    AveragePrice  Total Volume       4046        4225       4770  Total Bags  \
# 0          1.33    253.449443  32.198447  233.355630   6.939741   93.257010
# 1          1.35    234.258362  25.966902  211.278986   7.637408   97.496461
# 2          0.93    343.831674  28.190424  330.378071  11.423660   90.251593
# 3          1.08    281.055422  33.645208  268.284196   8.519390   76.230965
# 4          1.28    225.919455  30.683546  209.376193   8.705171   78.638095
#
#    Small Bags  Large Bags  XLarge Bags          type       year  region
# 0   92.755701    9.656604          0.0  conventional  44.888751  Albany
# 1   96.995206    9.873702          0.0  conventional  44.888751  Albany
# 2   89.678370   10.155787          0.0  conventional  44.888751  Albany
# 3   75.348524   11.565466          0.0  conventional  44.888751  Albany
# 4   77.370925   14.060228          0.0  conventional  44.888751  Albany

# %% [markdown]
# # Linear Regression Algorithm

# %%
#splitting x and y variables

df1_x=df.iloc[:,1:]
y=df.iloc[:,:1]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1_x['type']=le.fit_transform(df1_x['type'])

# %% [markdown]
# Finding: The data of average price of avocado depends on which type of avocado

# %%
df1_x['region'].nunique()
# Out:
# 51

# %%
#insert dummies for region
re=pd.get_dummies(df1['region'])
#concat dummies with original data
df1_x=pd.concat([df1_x,re],axis=1)
df1_x.drop(columns=['region'],inplace=True)

# %% [markdown]
# # Scaling data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(df1_x)

# %%
x
# Out:
# array([[-0.73306444, -0.75485401, -0.56687405, ..., -0.12944509,
#         -0.15590991, -0.13461354],
#        [-0.75471239, -0.76481011, -0.60652237, ..., -0.12944509,
#         -0.15590991, -0.13461354],
#        [-0.6311114 , -0.7612576 , -0.39262759, ..., -0.12944509,
#         -0.15590991, -0.13461354],
#        ...,
#        [-0.54249929, -0.46227429, -0.57292641, ..., -0.12944509,
#         -0.15590991, -0.13461354],
#        [-0.52839283, -0.43464616, -0.57020149, ..., -0.12944509,
#         -0.15590991, -0.13461354],
#        [-0.53643891, -0.47454432, -0.56788126, ..., -0.12944509,
#         -0.15590991, -0.13461354]])

# %%
#Model training

from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# # Machine learning Algorithms

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print('x_train.shape:',x_train.shape,'x_test.shape:',x_test.shape,'\ny_train.shape:',y_train.shape,'y_test.shape:',y_test.shape)
# Out:
# x_train.shape: (1213, 61) x_test.shape: (304, 61)
# y_train.shape: (1213, 1) y_test.shape: (304, 1)

# %%
from sklearn.metrics import mean_squared_error,r2_score
def models(model,x_train,x_test,y_train,y_test,score,rmse):
    
    model.fit(x_train,y_train)
    
    #predicting values
    y_pred=model.predict(x_test)
    
    score.append(model.score(x_train,y_train))
    rmse.append(np.sqrt(mean_squared_error(y_test,y_pred)))
    
    print('Score:',model.score(x_train,y_train))
    print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred)))
    print('r2 score:',r2_score(y_test,y_pred))

# %%
model_name,score,rmse=[],[],[]

# %%
#linear regression
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
mod='Linear Regression'
print('Model Report for',mod)
models(lreg,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model Report for Linear Regression
# Score: 0.7748273360929865
# RMSE: 0.08708022510130041
# r2 score: 0.7839163757216581

# %%
#ridge regression

from sklearn.linear_model import Ridge
parameters={'alpha':[0.01,1,100]}
best=GridSearchCV(Ridge(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 0.01}

# %%
rr=Ridge(alpha=0.01)
mod='Ridge Regression'
print('Model report for',mod)
models(rr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model report for Ridge Regression
# Score: 0.774756372228186
# RMSE: 0.08714197121315352
# r2 score: 0.7836098295695331

# %%
#Lasso Regression
from sklearn.linear_model import Lasso
parameters={'alpha':[0.001,0.01,1]}
best=GridSearchCV(Lasso(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 0.001}

# %%
lr=Lasso(alpha=0.001)
mod='Lasso Regression'
print('Model report for',mod)
models(lr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model report for Lasso Regression
# Score: 0.7008286816679485
# RMSE: 0.09977957791639254
# r2 score: 0.7162955849605137

# %%
from sklearn.linear_model import ElasticNet
en=ElasticNet(alpha=0.01)
mod='Elastic Net'
print('Model Report for',mod)
models(en,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model Report for Elastic Net
# Score: 0.625588218541522
# RMSE: 0.11142983825297723
# r2 score: 0.646177236922404

# %%
#Support Vector Regression
from sklearn.svm import SVR
parameters={'kernel':['linear','poly','rbf']}
best=GridSearchCV(SVR(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
svr=SVR(kernel='rbf')
mod='Support Vector Regression'
print('Model Report for',mod)
models(svr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model Report for Support Vector Regression
# Score: 0.7816620374371137
# RMSE: 0.09195767166493982
# r2 score: 0.7590323720435604

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
parameters={'max_depth':[8,10,12,15],'min_samples_leaf':[100,150]}
best=GridSearchCV(DecisionTreeRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 15, 'min_samples_leaf': 100}

# %%
dct=DecisionTreeRegressor(max_depth=15,min_samples_leaf=100)
mod='Decision Tree Regressor'
print('Model Report for',mod)
models(dct,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model Report for Decision Tree Regressor
# Score: 0.47727939350512
# RMSE: 0.13617488586303178
# r2 score: 0.47158296567021796

# %%
#Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
parameters={'n_estimators':[200,300,400],'max_depth':[5,6]}
best=GridSearchCV(RandomForestRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 200}

# %%
rfr=RandomForestRegressor(n_estimators=200,max_depth=6)
mod='Random Forest Regression'
print('Model report is',mod)
models(rfr,x_train,x_test,y_train,y_test,score,rmse)
model_name.append(mod)
# Out:
# Model report is Random Forest Regression
# Score: 0.8106297111718801
# RMSE: 0.09306146952135398
# r2 score: 0.7532128277703983

# %%
final=pd.DataFrame({'Model name':model_name,'Score':score,'RMSE':rmse})
final
# Out:
#                    Model name     Score      RMSE
# 0           Linear Regression  0.774827  0.087080
# 1            Ridge Regression  0.774756  0.087142
# 2            Lasso Regression  0.700829  0.099780
# 3                 Elastic Net  0.625588  0.111430
# 4   Support Vector Regression  0.781662  0.091958
# 5     Decision Tree Regressor  0.477279  0.136175
# 6     Decision Tree Regressor  0.477279  0.136175
# 7     Decision Tree Regressor  0.477279  0.136175
# 8     Decision Tree Regressor  0.477279  0.136175
# 9     Decision Tree Regressor  0.477279  0.136175
# 10    Decision Tree Regressor  0.477279  0.136175
# 11   Random Forest Regression  0.810630  0.093061

# %% [markdown]
# Observation:Random Forest Regression gives the best score for Linear regression.

# %%
#saving file
import joblib
from joblib import dump
joblib.dump(rfr,'Avocado_data.pkl')
# Out:
# ['Avocado_data.pkl']

# %% [markdown]
# # Classification

# %%
df2.head(5)
# Out:
#    AveragePrice  Total Volume       4046        4225       4770  Total Bags  \
# 0          1.33    253.449443  32.198447  233.355630   6.939741   93.257010
# 1          1.35    234.258362  25.966902  211.278986   7.637408   97.496461
# 2          0.93    343.831674  28.190424  330.378071  11.423660   90.251593
# 3          1.08    281.055422  33.645208  268.284196   8.519390   76.230965
# 4          1.28    225.919455  30.683546  209.376193   8.705171   78.638095
#
#    Small Bags  Large Bags  XLarge Bags          type       year  region
# 0   92.755701    9.656604          0.0  conventional  44.888751  Albany
# 1   96.995206    9.873702          0.0  conventional  44.888751  Albany
# 2   89.678370   10.155787          0.0  conventional  44.888751  Albany
# 3   75.348524   11.565466          0.0  conventional  44.888751  Albany
# 4   77.370925   14.060228          0.0  conventional  44.888751  Albany

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['type']=le.fit_transform(df2['type'])
df2.head(5)
# Out:
#    AveragePrice  Total Volume       4046        4225       4770  Total Bags  \
# 0          1.33    253.449443  32.198447  233.355630   6.939741   93.257010
# 1          1.35    234.258362  25.966902  211.278986   7.637408   97.496461
# 2          0.93    343.831674  28.190424  330.378071  11.423660   90.251593
# 3          1.08    281.055422  33.645208  268.284196   8.519390   76.230965
# 4          1.28    225.919455  30.683546  209.376193   8.705171   78.638095
#
#    Small Bags  Large Bags  XLarge Bags  type       year  region
# 0   92.755701    9.656604          0.0     0  44.888751  Albany
# 1   96.995206    9.873702          0.0     0  44.888751  Albany
# 2   89.678370   10.155787          0.0     0  44.888751  Albany
# 3   75.348524   11.565466          0.0     0  44.888751  Albany
# 4   77.370925   14.060228          0.0     0  44.888751  Albany

# %%
x=df2.drop(columns=['region'])
y=df2['region']

# %%
df2.region.describe()
# Out:
# count           1517
# unique            51
# top       California
# freq              76
# Name: region, dtype: object

# %%
le=LabelEncoder()
y=le.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 0, ..., 7, 7, 7])

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print('x_train.shape:',x_train.shape,'x_test.shape:',x_test.shape,'\ny_train.shape:',y_train.shape,'y_test.shape:',y_test.shape)
# Out:
# x_train.shape: (1213, 11) x_test.shape: (304, 11)
# y_train.shape: (1213,) y_test.shape: (304,)

# %%
from sklearn.metrics import classification_report,accuracy_score,roc_auc_score,plot_confusion_matrix,confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
#using labelbinarizer to convert y_test and y_pred

from sklearn.preprocessing import LabelBinarizer

# %%
def multiclass_roc_auc_score(y_test,y_pred):
    lb=LabelBinarizer()
    y_test_new=lb.fit_transform(y_test)
    y_pred_new=lb.fit_transform(y_pred)
    return round(roc_auc_score(y_test_new,y_pred_new)*100,2)

# %%
#Support Vector Regression

from sklearn.svm import SVC
svc=SVC()
svc_parameters={'kernel':['linear','sigmoid','poly','rbf'],'C':[1,10]}
bsvc=GridSearchCV(svc,svc_parameters)
bsvc.fit(x_train,y_train)
bsvc.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
svc=SVC(kernel='linear',C=10)
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
svc_score=round(accuracy_score(y_test,y_pred)*100,2)
print('svc_score:',svc_score,'%\nmulticlass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# svc_score: 95.72 %
# multiclass_roc_auc_score: 98.11 %

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()
neighbors={'n_neighbors':range(1,30)}
bknn=GridSearchCV(knn,neighbors)
bknn.fit(x_train,y_train)
bknn.best_params_
# Out:
# {'n_neighbors': 1}

# %%
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
knn_score=round(accuracy_score(y_test,y_pred)*100,2)
print('knn_score:',knn_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# knn_score: 95.39 %multiclass_roc_auc_score: 97.85 %

# %%
#Decision Tree Classifier

from sklearn.tree import DecisionTreeClassifier
criterion={'criterion':['gini','entropy']}
dtc=DecisionTreeClassifier(random_state=42)
bdtc=GridSearchCV(dtc,criterion)
bdtc.fit(x_train,y_train)
bdtc.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
dtc=DecisionTreeClassifier(criterion='entropy',random_state=42)
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
dtc_score=round(accuracy_score(y_test,y_pred)*100,2)
print('dtc_score:',dtc_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# dtc_score: 89.47 %multiclass_roc_auc_score: 94.55 %

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
parameters={'n_estimators':range(100,200,300)}
rf=RandomForestClassifier(random_state=42)
brf=GridSearchCV(rf,parameters)
brf.fit(x_train,y_train)
brf.best_params_
# Out:
# {'n_estimators': 100}

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
rf_score=round(accuracy_score(y_test,y_pred)*100,2)
print('rf_score:',rf_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# rf_score: 97.7 %multiclass_roc_auc_score: 98.82 %

# %%
#Gradient Boost Classifier
from sklearn.ensemble import GradientBoostingClassifier

gbc=GradientBoostingClassifier(n_estimators=250)
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)
gbc_score=round(accuracy_score(y_test,y_pred)*100,2)
print('gbc_score:',gbc_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# gbc_score: 91.45 %multiclass_roc_auc_score: 95.12 %

# %%
#Extra Trees Classifier

from sklearn.ensemble import ExtraTreesClassifier

etc=ExtraTreesClassifier(n_estimators=250)
etc.fit(x_train,y_train)
y_pred=etc.predict(x_test)
etc_score=round(accuracy_score(y_test,y_pred)*100,2)
print('etc_score:',etc_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# etc_score: 98.03 %multiclass_roc_auc_score: 98.98 %

# %%
#AdaBoost Classifier
from sklearn.ensemble import AdaBoostClassifier

ada=AdaBoostClassifier(n_estimators=100)
ada.fit(x_train,y_train)
y_pred=ada.predict(x_test)
ada_score=round(accuracy_score(y_test,y_pred)*100,2)
print('ada_score:',ada_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# ada_score: 9.54 %multiclass_roc_auc_score: 49.97 %

# %%
#Bagging Classifier
from sklearn.ensemble import BaggingClassifier

bc=BaggingClassifier(n_estimators=250)
bc.fit(x_train,y_train)
y_pred=bc.predict(x_test)
bc_score=round(accuracy_score(y_test,y_pred)*100,2)
print('bc_score:',bc_score,'%multiclass_roc_auc_score:',multiclass_roc_auc_score(y_test,y_pred),'%')
plt.figure(figsize=(20,12))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# bc_score: 95.07 %multiclass_roc_auc_score: 97.39 %

# %%
models={
    'SVC':svc,
    'KNeighborsClassifier':knn,
    'DecisionTreeClassifier':dtc,
    'RandomForestClassifier':rf,
    'GradientBoostingClassifier':gbc,
    'ExtraTreesClassifier':etc,
    'AdaBoostClassifier':ada,
    'BaggingClassifier':bc,
}

# %%
models_name,ascore,roc=[],[],[]
for name in models.keys():
    models[name].fit(x_train,y_train)
    models_name.append(name)
    y_pred=models[name].predict(x_test)
    ascore.append(round(accuracy_score(y_test,y_pred)*100,2))
    roc.append(multiclass_roc_auc_score(y_test,y_pred))

# %%
final=pd.DataFrame({'Model':models_name,'Accuracy_score':ascore,'ROC_AUC_score':roc}).sort_values(by='Accuracy_score',ascending=False)
final
# Out:
#                         Model  Accuracy_score  ROC_AUC_score
# 5        ExtraTreesClassifier           98.36          99.04
# 3      RandomForestClassifier           97.70          98.82
# 0                         SVC           95.72          98.11
# 7           BaggingClassifier           95.72          97.52
# 1        KNeighborsClassifier           95.39          97.85
# 4  GradientBoostingClassifier           90.13          68.29
# 2      DecisionTreeClassifier           89.47          94.55
# 6          AdaBoostClassifier            5.26          50.01

# %% [markdown]
# Conclusion:
#     In the above data set the feature 'region' is taken as output for classification.
#     Here the highest accuracy is acheived by the ExtraTreesClassifier model with 98% accuracy.

# %%
joblib.dump(etc,'EC_Avocado.pkl')
# Out:
# ['EC_Avocado.pkl']
